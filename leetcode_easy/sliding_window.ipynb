# %% [markdown]
# # Best Time to Buy and Sell Stock

# %% [markdown]
# ![sliding_window_best_time_to_buy_and_sell_stock-2.jpg](attachment:sliding_window_best_time_to_buy_and_sell_stock-2.jpg)

# %%
from typing import List


class Solution:
    def max_profit(self, s: List) -> int:
        l = 0
        cur_profit = 0
        for r in range(1, len(s)):
            if s[r] <= s[l]:
                # update l to be = to r
                l = r
            cur_profit = max(cur_profit, s[r] - s[l])
        return cur_profit


sol = Solution()
sol.max_profit([7, 1, 5, 3, 6, 4])
# Out:
# 5
